# %%
# %reload_ext autoreload
# %autoreload 1
# %aimport network

# %matplotlib inline

import network
import numpy as np
from skimage import data
from IPython.display import Image, display

import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
sizes = [2, 3, 1]

# %%
sizes[:-1]
# Out:
# [2, 3]

# %%
sizes[1:]
# Out:
# [3, 1]

# %%
net = network.Network(sizes)

# %%
net.biases
# Out:
# [array([[ 0.84844127],
#         [-1.47500175],
#         [ 0.94479494]]), array([[-0.07546335]])]

# %%
net.weights
# Out:
# [array([[-1.47407438, -2.00609607],
#         [-1.84465707, -0.16565507],
#         [-1.85294125, -0.19088853]]),
#  array([[-1.57253888, -0.1109847 ,  0.03059661]])]

# %%
im1 = data.imread('sample/10_left_conv.jpeg')
plt.imshow(im1)
