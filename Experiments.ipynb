# %%
# %reload_ext autoreload
# %autoreload 1
# %aimport network

# %matplotlib inline

import network
import numpy as np
from skimage import data
from IPython.display import Image, display

import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
sizes = [2, 3, 1]

# %%
sizes[:-1]
# Out:
# [2, 3]

# %%
sizes[1:]
# Out:
# [3, 1]

# %%
net = network.Network([2, 3, 1])

# %%
net.biases
# Out:
# [array([[-0.26389175],
#         [-1.09859064],
#         [-0.55610007]]), array([[ 0.28424357]])]

# %%
im = data.imread('sample/10_left.jpeg')
n_rows, n_cols, n_channels = im.shape
display(n_rows, n_cols, n_channels)
plt.imshow(im)
# Out:
# 3168
# 4752
# 3

# %%
im1 = data.imread('sample/10_left_conv.jpeg')
plt.imshow(im1)
